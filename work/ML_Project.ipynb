# %% [markdown]
# ## Assignment List (80 points)
# **Make sure you excute every cell in order, and reserve the outputs of every cell.**
# 1. Transform and plot image. (15 points)
# 2. Data loading. (10 points)
# 3. Train the baseline model and plot the learning curve. (15 points)
#
# 4. Comparison and analysis (20 points)
#     * Compare the training results of 5, 20, and 50 epochs.
#     * Use `torch.optim.Adam()` with a learning rate of 0.001 as the optimizer.
#     * Try a different data_transform function
# 5. Double the number of hidden units in your model and train it for 20 epochs, what happens to the results? (10 points)
# 6. Make a prediction on your own custom image of pizza/steak/sushi (you could even download one from the internet) and share your prediction. (10 points)
#     * Does the model you trained get it right?
#     * If not, what do you think you could do to improve it?
#
# ## Advanced options (20 points)
# **Make sure you excute every cell in order, and reserve the outputs of every cell.**
# - A1: Train a complicated model on the dataset (ResNet18) (10 points) \
#     **Remenber to resize the image data and recall dataloader**.
# - A2: Compare the performance of a simple model (provided by the template) and the complicated model. (5 points)
#       Plot learning curves in the same figure axes
# - A3: Usage of git version control (5 points)
#       Git add, git commit, git log, insert a screenshot within this notebook
#
# ### Deadline: 11.59 pm 16/01/2023
# ### Submit a rar/zip folder to brightspace under the unit of **Machine Learning for Media Production**

# %% [markdown]
# ## 0. Importing PyTorch and setting up device-agnostic code

# %%
import torch
from torch import nn

# Note: this notebook requires torch >= 1.10.0
# Setup device-agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.__version__, device
# Out:
# /home/s5321302/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/torch/cuda/__init__.py:83: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# ('1.12.1+cu102', 'cpu')

# %% [markdown]
# ## 1. Get data
# [Food101 dataset](https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101/) is popular computer vision benchmark as it contains 1000 images of 101 different kinds of foods, totaling 101,000 images (75,750 train and 25,250 test).
# In this assignment, only 3 classes are used to form a small classification dataset, it contains pizza, steak and sushi.
# And instead of 1,000 images per class, ervey image class only has 100 images(10%).

# %%
import requests
import zipfile
from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi"

# If the image folder doesn't exist, download it and prepare it... 
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)
    
    # Download pizza, steak, sushi data
    with open(data_path / "pizza_steak_sushi.zip", "wb") as f:
        request = requests.get("https://github.com/lizhiqihhh/AIM-MLWorkshop/raw/main/pizza_steak_sushi.zip")
        print("Downloading pizza, steak, sushi data...")
        f.write(request.content)

    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(data_path / "pizza_steak_sushi.zip", "r") as zip_ref:
        print("Unzipping pizza, steak, sushi data...") 
        zip_ref.extractall(image_path)
# Out:
# data/pizza_steak_sushi directory exists.

# %%
# Setup train and testing paths
train_dir = image_path / "train"
test_dir = image_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('data/pizza_steak_sushi/train'),
#  PosixPath('data/pizza_steak_sushi/test'))

# %% [markdown]
# ## Task 1
#
# 1. Transform training dataset and testing dataset.
# 2. Plot images

# %% [markdown]
# ## 1.1 Transforming data

# %%
# import libraries and packages
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# Write transform for image
data_transform = transforms.Compose([
    # Step 1: Resize the images to 64x64
    transforms.Resize([64,64]),
    # Resize the images to 64x64x3 (64 height, 64 width, 3 color channels)
    # Step 2: Turn the image into a torch.Tensor
    # converts all pixel values from 0-255 to be between 0-1  
    
    # Step 3: RandomHorizontalFlip---Flip the images randomly on the horizontal p = probability of flip, 0.5 = 50% chance 
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

# %%
# Use ImageFolder to create dataset(s)
from torchvision import datasets
train_data = datasets.ImageFolder(root=train_dir, # root should be the target folder of images
                                  transform=data_transform, # transform should be a set of transform functions to perform on images
                                  target_transform=None) # transforms to perform on labels (if necessary)

test_data = datasets.ImageFolder(root=test_dir, # it should be the folder of test data 
                                 transform=data_transform) # same with transform applied to train_data

print(f"Train data:\n{train_data}\nTest data:\n{test_data}")
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 225
#     Root location: data/pizza_steak_sushi/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=[64, 64], interpolation=bilinear, max_size=None, antialias=None)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 75
#     Root location: data/pizza_steak_sushi/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=[64, 64], interpolation=bilinear, max_size=None, antialias=None)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %%
len(train_data), len(test_data)
# Out:
# (225, 75)

# %% [markdown]
# ## 1.2 Plot the transformed image
# `Plot_imgs` and `plot_transformed_images` are defined in plot.py, complete the contents in plot.py

# %%
from pathlib import Path
from plot import Plot_imgs
# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi"

# Plot an image using matplotlib
# Please complete the plot.py before use this plotting function
Plot_imgs(image_path)

# %%
from plot import plot_transformed_images
image_path_list = list(image_path.glob("*/*/*.jpg"))
plot_transformed_images(image_path_list, 
                        transform=data_transform, 
                        n=3)

# %%
# Get class names as a list
class_names = train_data.classes
# Try index on the `train_data` and `test_data` `Dataset`'s to find samples and their target labels.
img, label = train_data[0][0], train_data[0][1]
# Print the shape/content/datatype of img and label
print(img)
print(label)
# Out:
# tensor([[[0.1137, 0.1020, 0.0980,  ..., 0.1255, 0.1216, 0.1176],
#          [0.1059, 0.0980, 0.0980,  ..., 0.1294, 0.1294, 0.1294],
#          [0.1020, 0.0980, 0.0941,  ..., 0.1333, 0.1333, 0.1333],
#          ...,
#          [0.1098, 0.1098, 0.1255,  ..., 0.1686, 0.1647, 0.1686],
#          [0.0863, 0.0941, 0.1098,  ..., 0.1686, 0.1647, 0.1686],
#          [0.0863, 0.0863, 0.0980,  ..., 0.1686, 0.1647, 0.1647]],
#
#         [[0.0745, 0.0706, 0.0745,  ..., 0.0588, 0.0588, 0.0588],
#          [0.0706, 0.0706, 0.0745,  ..., 0.0627, 0.0627, 0.0627],
#          [0.0706, 0.0745, 0.0745,  ..., 0.0706, 0.0706, 0.0706],
#          ...,
#          [0.1255, 0.1333, 0.1373,  ..., 0.2510, 0.2392, 0.2392],
#          [0.1098, 0.1176, 0.1255,  ..., 0.2510, 0.2392, 0.2314],
#          [0.1020, 0.1059, 0.1137,  ..., 0.2431, 0.2353, 0.2275]],
#
#         [[0.0941, 0.0902, 0.0902,  ..., 0.0196, 0.0196, 0.0196],
#          [0.0902, 0.0863, 0.0902,  ..., 0.0196, 0.0157, 0.0196],
#          [0.0902, 0.0902, 0.0902,  ..., 0.0157, 0.0157, 0.0196],
#          ...,
#          [0.1294, 0.1333, 0.1490,  ..., 0.1961, 0.1882, 0.1804],
#          [0.1098, 0.1137, 0.1255,  ..., 0.1922, 0.1843, 0.1804],
#          [0.1059, 0.1020, 0.1059,  ..., 0.1843, 0.1804, 0.1765]]])
# 0

# %%
import matplotlib.pyplot as plt
from PIL import Image
img_permute = img.permute(1, 2, 0)

# Print out different shapes (before and after permute)
print(f"Original shape: {img.shape} -> [color_channels, height, width]")
print(f"Image permute shape: {img_permute.shape} -> [height, width, color_channels]")


# ---------------Plot the permuted image-------------
plt.figure()
plt.imshow(img_permute)
# ---------------End of code------------------------
plt.axis("off")
plt.title(class_names[label], fontsize=14)
# Out:
# Original shape: torch.Size([3, 64, 64]) -> [color_channels, height, width]
# Image permute shape: torch.Size([64, 64, 3]) -> [height, width, color_channels]
# Text(0.5, 1.0, 'pizza')

# %% [markdown]
# ## 1.3 Turn loaded images into `DataLoader`'s

# %% [markdown]
# ## Task 2: Turn train and test Datasets into DataLoaders (10 points)

# %%
from torch.utils.data import DataLoader
train_dataloader = DataLoader(train_data,shuffle = True) # shuffle training data

test_dataloader = DataLoader(test_data) # don't usually need to shuffle testing data

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f56f46ff6d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f56f46fff70>)

# %%
# Load a batch of images in the training dataset
img, label = next(iter(train_dataloader))

print(f"Image shape: {img.shape} -> [batch_size, color_channels, height, width]")
print(f"Label shape: {label.shape}")
# Out:
# Image shape: torch.Size([1, 3, 64, 64]) -> [batch_size, color_channels, height, width]
# Label shape: torch.Size([1])

# %% [markdown]
# `display_random_images` is defined in plot.py, please complete the contents in `plot.py`

# %%
# Display random images from Dataset
from plot import display_random_images
display_random_images(train_data, 
                      n=12, 
                      classes=class_names,
                      seed=42)
# Out:
# For display purposes, n shouldn't be larger than 10, setting to 10 and removing shape display.

# %% [markdown]
# ## Task 3 Model_0 training
# ### Task 3.1 Train the baseline model TinyVGG

# %%
from TinyVGG import TinyVGG 
#import the model from TinyVGG.py
torch.manual_seed(42)

# --------------Initialize the TinyVGG model--------------
'''
    Parameters: input_shape
                hidden_units
                output_shape
'''
model_0 = TinyVGG(input_shape=3,hidden_units=10,output_shape=3).to(device)
# -------------------  End of code -----------------------

model_0 # Print the model info here!
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_3): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=640, out_features=3, bias=True)
#   )
# )

# %%
# 1. Get a batch of images and labels from the DataLoader
img_batch, label_batch = next(iter(train_dataloader))

# 2. Get a single image from the batch and unsqueeze the image so its shape fits the model
img_single, label_single = img_batch[0].unsqueeze(dim=0), label_batch[0]
print(f"Single image shape: {img_single.shape}\n")

# 3. Perform a forward pass on a single image
model_0.eval()
with torch.inference_mode():
    pred = model_0(img_single.to(device))
    
# 4. Print out what's happening and convert model logits -> pred probs -> pred label
print(f"Output logits:\n{pred}\n")
print(f"Output prediction probabilities:\n{torch.softmax(pred, dim=1)}\n")
print(f"Output prediction label:\n{torch.argmax(torch.softmax(pred, dim=1), dim=1)}\n")
print(f"Actual label:\n{label_single}")
# Out:
# Single image shape: torch.Size([1, 3, 64, 64])
#
# Output logits:
# tensor([[ 0.0213,  0.0190, -0.0162]])
#
# Output prediction probabilities:
# tensor([[0.3377, 0.3370, 0.3253]])
#
# Output prediction label:
# tensor([0])
#
# Actual label:
# 0

# %%
# Load the training function from TinyVGG.py
from TinyVGG import train
# Set random seeds
torch.manual_seed(42) 
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_0.parameters(), lr=0.0001)

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# ------------------------- Train model_0 --------------------------
# Fill in the parentheses with parameters needed in the train function
model_0_results = train(model_0,train_dataloader,test_dataloader, optimizer,loss_fn,NUM_EPOCHS)
# -------------------------  End of code  --------------------------
# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1001 | train_acc: 0.2622 | test_loss: 1.1007 | test_acc: 0.2267
# Epoch: 2 | train_loss: 1.0998 | train_acc: 0.3200 | test_loss: 1.1021 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0996 | train_acc: 0.3200 | test_loss: 1.1021 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0992 | train_acc: 0.3467 | test_loss: 1.1019 | test_acc: 0.3333
# Epoch: 5 | train_loss: 1.0993 | train_acc: 0.3333 | test_loss: 1.1014 | test_acc: 0.3333
# Total training time: 9.181 seconds

# %% [markdown]
# ### Task 3.2: Plot the loss curves of Model_0
#
# From the print outs of our `model_0` training, it didn't look like it did too well.
#
# Create a function to plot the values in the `model_0_results` dictionary.

# %%
from typing import Tuple, Dict, List
def plot_loss_curves(results: Dict[str, List[float]]):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """
    
    # Get the loss values of the results dictionary (training and test)
    train_loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    train_accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot 
    plt.figure(figsize=(15, 7))

    # --------------- Complete the following lines --------------
    # Plot loss, please include label, title, and legend in the figure
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss ,label = 'Train_loss')   # plot epochs, train_loss
    plt.plot(epochs, test_loss ,label = 'Test_loss')   # plot epochs, test_loss
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracy ,label = 'Train_acc') # plot epochs, train_accuracy, add label
    plt.plot(epochs, test_accuracy ,label = 'Test_acc')# plot epochs, test_accuracy, add label
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend()
    # ---------------------- End of codes -----------------------

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# `torchinfo` comes with a `summary()` method that takes a PyTorch model as well as an `input_shape` and returns what happens as a tensor moves through your model.

# %%
try: 
    import torchinfo
except:
    # !pip install torchinfo
    import torchinfo
    
from torchinfo import summary
summary(model_0, input_size=[1, 3, 64, 64]) # do a test pass through of an example input size
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGG                                  [1, 3]                    --
# ├─Sequential: 1-1                        [1, 10, 32, 32]           --
# │    └─Conv2d: 2-1                       [1, 10, 64, 64]           280
# │    └─ReLU: 2-2                         [1, 10, 64, 64]           --
# │    └─Conv2d: 2-3                       [1, 10, 64, 64]           910
# │    └─ReLU: 2-4                         [1, 10, 64, 64]           --
# │    └─MaxPool2d: 2-5                    [1, 10, 32, 32]           --
# ├─Sequential: 1-2                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-6                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-7                         [1, 10, 32, 32]           --
# │    └─Conv2d: 2-8                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-9                         [1, 10, 32, 32]           --
# │    └─MaxPool2d: 2-10                   [1, 10, 16, 16]           --
# ├─Sequential: 1-3                        [1, 10, 8, 8]             --
# │    └─Conv2d: 2-11                      [1, 10, 16, 16]           910
# │    └─ReLU: 2-12                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-13                      [1, 10, 16, 16]           910
# │    └─ReLU: 2-14                        [1, 10, 16, 16]           --
# │    └─MaxPool2d: 2-15                   [1, 10, 8, 8]             --
# ├─Sequential: 1-4                        [1, 3]                    --
# │    └─Flatten: 2-16                     [1, 640]                  --
# │    └─Linear: 2-17                      [1, 3]                    1,923
# ==========================================================================================
# Total params: 6,753
# Trainable params: 6,753
# Non-trainable params: 0
# Total mult-adds (M): 7.21
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.86
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.94
# ==========================================================================================

# %% [markdown]
# ## Task 4: Comparison and analysis

# %% [markdown]
# ### Task 4.1 Try different epochs

# %%
# Train for 5 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)
# create a new instance of TinyVGG model
model_e_5 = TinyVGG(3,10,3).to(device)

loss_fn=nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_e_5.parameters(), lr=0.0005)

model_e_5_results = train(model_e_5,train_dataloader,test_dataloader, optimizer,loss_fn,5)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1026 | train_acc: 0.2800 | test_loss: 1.1012 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.1005 | train_acc: 0.3511 | test_loss: 1.1002 | test_acc: 0.2400
# Epoch: 3 | train_loss: 1.1028 | train_acc: 0.3333 | test_loss: 1.1032 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.1021 | train_acc: 0.2933 | test_loss: 1.0966 | test_acc: 0.3467
# Epoch: 5 | train_loss: 1.0919 | train_acc: 0.4178 | test_loss: 1.0889 | test_acc: 0.4400

# %%
# Train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)
model_e_20 = TinyVGG(3,10,3).to(device)

loss_fn=nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_e_20.parameters(), lr=0.0001)
model_e_20_results = train(model_e_20,train_dataloader,test_dataloader, optimizer,loss_fn,20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0995 | train_acc: 0.3467 | test_loss: 1.1012 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.0992 | train_acc: 0.3467 | test_loss: 1.1020 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.1000 | train_acc: 0.2667 | test_loss: 1.1025 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0997 | train_acc: 0.3244 | test_loss: 1.1009 | test_acc: 0.3333
# Epoch: 5 | train_loss: 1.0993 | train_acc: 0.3467 | test_loss: 1.1014 | test_acc: 0.3333
# Epoch: 6 | train_loss: 1.0992 | train_acc: 0.3467 | test_loss: 1.1024 | test_acc: 0.3333
# Epoch: 7 | train_loss: 1.0990 | train_acc: 0.3467 | test_loss: 1.1020 | test_acc: 0.3333
# Epoch: 8 | train_loss: 1.0986 | train_acc: 0.3467 | test_loss: 1.1018 | test_acc: 0.3333
# Epoch: 9 | train_loss: 1.0966 | train_acc: 0.3733 | test_loss: 1.0980 | test_acc: 0.3333
# Epoch: 10 | train_loss: 1.0875 | train_acc: 0.3556 | test_loss: 1.0830 | test_acc: 0.4133
# Epoch: 11 | train_loss: 1.0105 | train_acc: 0.5244 | test_loss: 1.0400 | test_acc: 0.4133
# Epoch: 12 | train_loss: 0.9096 | train_acc: 0.5778 | test_loss: 1.0246 | test_acc: 0.4400
# Epoch: 13 | train_loss: 0.8868 | train_acc: 0.5956 | test_loss: 1.0376 | test_acc: 0.4800
# Epoch: 14 | train_loss: 0.8562 | train_acc: 0.6444 | test_loss: 1.0256 | test_acc: 0.4667
# Epoch: 15 | train_loss: 0.8456 | train_acc: 0.6311 | test_loss: 1.0120 | test_acc: 0.4667
# Epoch: 16 | train_loss: 0.8392 | train_acc: 0.6356 | test_loss: 1.0042 | test_acc: 0.4667
# Epoch: 17 | train_loss: 0.8331 | train_acc: 0.6578 | test_loss: 1.0231 | test_acc: 0.4133
# Epoch: 18 | train_loss: 0.8191 | train_acc: 0.6667 | test_loss: 1.0371 | test_acc: 0.4667
# Epoch: 19 | train_loss: 0.8194 | train_acc: 0.6533 | test_loss: 1.0019 | test_acc: 0.4533
# Epoch: 20 | train_loss: 0.8127 | train_acc: 0.6622 | test_loss: 1.0739 | test_acc: 0.4800

# %%
# Train for 50 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)
model_e_50 = TinyVGG(3,10,3).to(device)

loss_fn=nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_e_50.parameters(), lr=0.0001)

model_e_50_results = train(model_e_50,train_dataloader,test_dataloader, optimizer,loss_fn,50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0995 | train_acc: 0.3467 | test_loss: 1.1012 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.0992 | train_acc: 0.3467 | test_loss: 1.1020 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.1000 | train_acc: 0.2667 | test_loss: 1.1025 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0997 | train_acc: 0.3244 | test_loss: 1.1009 | test_acc: 0.3333
# Epoch: 5 | train_loss: 1.0993 | train_acc: 0.3467 | test_loss: 1.1014 | test_acc: 0.3333
# Epoch: 6 | train_loss: 1.0992 | train_acc: 0.3467 | test_loss: 1.1024 | test_acc: 0.3333
# Epoch: 7 | train_loss: 1.0990 | train_acc: 0.3467 | test_loss: 1.1020 | test_acc: 0.3333
# Epoch: 8 | train_loss: 1.0986 | train_acc: 0.3467 | test_loss: 1.1018 | test_acc: 0.3333
# Epoch: 9 | train_loss: 1.0966 | train_acc: 0.3733 | test_loss: 1.0980 | test_acc: 0.3333
# Epoch: 10 | train_loss: 1.0875 | train_acc: 0.3556 | test_loss: 1.0830 | test_acc: 0.4133
# Epoch: 11 | train_loss: 1.0105 | train_acc: 0.5244 | test_loss: 1.0400 | test_acc: 0.4133
# Epoch: 12 | train_loss: 0.9096 | train_acc: 0.5778 | test_loss: 1.0246 | test_acc: 0.4400
# Epoch: 13 | train_loss: 0.8868 | train_acc: 0.5956 | test_loss: 1.0376 | test_acc: 0.4800
# Epoch: 14 | train_loss: 0.8562 | train_acc: 0.6444 | test_loss: 1.0256 | test_acc: 0.4667
# Epoch: 15 | train_loss: 0.8456 | train_acc: 0.6311 | test_loss: 1.0120 | test_acc: 0.4667
# Epoch: 16 | train_loss: 0.8392 | train_acc: 0.6356 | test_loss: 1.0042 | test_acc: 0.4667
# Epoch: 17 | train_loss: 0.8331 | train_acc: 0.6578 | test_loss: 1.0231 | test_acc: 0.4133
# Epoch: 18 | train_loss: 0.8191 | train_acc: 0.6667 | test_loss: 1.0371 | test_acc: 0.4667
# Epoch: 19 | train_loss: 0.8194 | train_acc: 0.6533 | test_loss: 1.0019 | test_acc: 0.4533
# Epoch: 20 | train_loss: 0.8127 | train_acc: 0.6622 | test_loss: 1.0739 | test_acc: 0.4800
# Epoch: 21 | train_loss: 0.8119 | train_acc: 0.6578 | test_loss: 1.0103 | test_acc: 0.4933
# Epoch: 22 | train_loss: 0.8050 | train_acc: 0.6711 | test_loss: 1.0128 | test_acc: 0.4667
# Epoch: 23 | train_loss: 0.7955 | train_acc: 0.6756 | test_loss: 1.0110 | test_acc: 0.4800
# Epoch: 24 | train_loss: 0.7895 | train_acc: 0.6667 | test_loss: 1.0157 | test_acc: 0.4933
# Epoch: 25 | train_loss: 0.7931 | train_acc: 0.6756 | test_loss: 1.0278 | test_acc: 0.4667
# Epoch: 26 | train_loss: 0.7802 | train_acc: 0.6533 | test_loss: 1.0255 | test_acc: 0.4533
# Epoch: 27 | train_loss: 0.7746 | train_acc: 0.6667 | test_loss: 1.0167 | test_acc: 0.4533
# Epoch: 28 | train_loss: 0.7843 | train_acc: 0.7200 | test_loss: 1.0189 | test_acc: 0.4533
# Epoch: 29 | train_loss: 0.7724 | train_acc: 0.6844 | test_loss: 1.0068 | test_acc: 0.4800
# Epoch: 30 | train_loss: 0.7689 | train_acc: 0.6756 | test_loss: 1.0002 | test_acc: 0.4933
# Epoch: 31 | train_loss: 0.7670 | train_acc: 0.6978 | test_loss: 1.0101 | test_acc: 0.5200
# Epoch: 32 | train_loss: 0.7706 | train_acc: 0.6711 | test_loss: 1.0112 | test_acc: 0.4933
# Epoch: 33 | train_loss: 0.7534 | train_acc: 0.6844 | test_loss: 1.0364 | test_acc: 0.5333
# Epoch: 34 | train_loss: 0.7416 | train_acc: 0.7111 | test_loss: 1.0230 | test_acc: 0.4800
# Epoch: 35 | train_loss: 0.7378 | train_acc: 0.6933 | test_loss: 1.0059 | test_acc: 0.4933
# Epoch: 36 | train_loss: 0.7398 | train_acc: 0.6711 | test_loss: 1.0265 | test_acc: 0.5067
# Epoch: 37 | train_loss: 0.7352 | train_acc: 0.7067 | test_loss: 1.0528 | test_acc: 0.5067
# Epoch: 38 | train_loss: 0.7280 | train_acc: 0.6978 | test_loss: 1.0051 | test_acc: 0.5333
# Epoch: 39 | train_loss: 0.7281 | train_acc: 0.7111 | test_loss: 1.0240 | test_acc: 0.4933
# Epoch: 40 | train_loss: 0.7286 | train_acc: 0.6889 | test_loss: 1.0234 | test_acc: 0.5067
# Epoch: 41 | train_loss: 0.7187 | train_acc: 0.6800 | test_loss: 1.0673 | test_acc: 0.4800
# Epoch: 42 | train_loss: 0.7104 | train_acc: 0.7156 | test_loss: 1.1034 | test_acc: 0.4800
# Epoch: 43 | train_loss: 0.7120 | train_acc: 0.7111 | test_loss: 1.0095 | test_acc: 0.5200
# Epoch: 44 | train_loss: 0.7003 | train_acc: 0.7200 | test_loss: 1.0409 | test_acc: 0.4800
# Epoch: 45 | train_loss: 0.6936 | train_acc: 0.7067 | test_loss: 1.0200 | test_acc: 0.4800
# Epoch: 46 | train_loss: 0.6928 | train_acc: 0.7156 | test_loss: 1.0482 | test_acc: 0.5067
# Epoch: 47 | train_loss: 0.6860 | train_acc: 0.7022 | test_loss: 1.0277 | test_acc: 0.5200
# Epoch: 48 | train_loss: 0.6782 | train_acc: 0.7422 | test_loss: 1.0042 | test_acc: 0.5600
# Epoch: 49 | train_loss: 0.6691 | train_acc: 0.7200 | test_loss: 1.0385 | test_acc: 0.4933
# Epoch: 50 | train_loss: 0.6611 | train_acc: 0.7556 | test_loss: 1.0030 | test_acc: 0.5333

# %% [markdown]
# ### Compare: Print the differences

# %%
import pandas as pd 
model_compare_1 = pd.DataFrame(model_e_5_results)
model_compare_2 = pd.DataFrame(model_e_20_results)
model_compare_3 = pd.DataFrame(model_e_50_results)

model_compare_1
# Out:
#    train_loss  train_acc  test_loss  test_acc
# 0    1.102647   0.280000   1.101174  0.333333
# 1    1.100458   0.351111   1.100197  0.240000
# 2    1.102768   0.333333   1.103179  0.333333
# 3    1.102130   0.293333   1.096589  0.346667
# 4    1.091923   0.417778   1.088852  0.440000

# %% [markdown]
# ### Analysis: What you find and how to improve model_0's performance?

# %% [markdown]
# **Your answer**:
# We can adjust the parameters of the model to give it the best performance.For example, firstly, we can adjust the learning rate of the model.Secondly, we can increase the number of epochs of the model.Finally, we can also increase the number of layers of the model.

# %% [markdown]
# ### Task 4.2 Try different data transform functions

# %%
import os
BATCH_SIZE = 32
NUM_WORKERS = os.cpu_count()

torch.manual_seed(42)
# --------- Create training transform with TrivialAugment ---------
# TrivialAugment: Tuning-Free Yet State-of-the-Art Data Augmentation (source:https://arxiv.org/abs/2103.10158)
train_transform_trivial_augment = transforms.Compose([
    # Resize
    transforms.Resize([64,64]),
    # RandomHorizontalFlip
    transforms.RandomHorizontalFlip,
    # TrivialAugment
    transforms.TrivialAugmentWide(fill=10),
    # ToTensor
    transforms.ToTensor()
])

train_data_augmented = datasets.ImageFolder(train_dir, transform=train_transform_trivial_augment)

train_dataloader_augmented = DataLoader(train_data,BATCH_SIZE,shuffle=True)
test_dataloader_simple = DataLoader(test_data,BATCH_SIZE,shuffle=False)
# ---------------------- End of code ----------------------

train_dataloader_augmented, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f56dc556370>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f56f46fff70>)

# %%
# Create model_1 and send it to the target device
torch.manual_seed(42)
model_1 = TinyVGG(3,10,3).to(device)
model_1 # print model_1
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_3): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=640, out_features=3, bias=True)
#   )
# )

# %%
# Set random seeds
torch.manual_seed(42) 
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_1.parameters(), lr=0.001)

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# ------------------------- Train model_1 ----------------------------
# Fill in the parentheses with parameters needed in the train function
model_1_results = train(model_1,train_dataloader_augmented,test_dataloader,optimizer,loss_fn,NUM_EPOCHS)
# ------------------------- End of model_1 ---------------------------
# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1016 | train_acc: 0.2500 | test_loss: 1.0983 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.1015 | train_acc: 0.3047 | test_loss: 1.0980 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0929 | train_acc: 0.4258 | test_loss: 1.0949 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.1098 | train_acc: 0.3047 | test_loss: 1.0960 | test_acc: 0.3333
# Epoch: 5 | train_loss: 1.0935 | train_acc: 0.4258 | test_loss: 1.1008 | test_acc: 0.3333
# Total training time: 7.032 seconds

# %% [markdown]
# ## Task 5: Double the number of hidden units in your model and train it for 20 epochs

# %%
# Double the number of hidden units and train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)
model_2 = TinyVGG(3,20,3).to(device) # use 20 hidden units instead of 10

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(), lr=0.001)

model_2_results = train(model_2,train_dataloader_augmented,test_dataloader,optimizer,loss_fn,20) # train for 20 epochs
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1015 | train_acc: 0.2852 | test_loss: 1.0974 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.0953 | train_acc: 0.4102 | test_loss: 1.0931 | test_acc: 0.4133
# Epoch: 3 | train_loss: 1.1018 | train_acc: 0.2812 | test_loss: 1.0905 | test_acc: 0.4133
# Epoch: 4 | train_loss: 1.0979 | train_acc: 0.2812 | test_loss: 1.0916 | test_acc: 0.4133
# Epoch: 5 | train_loss: 1.1006 | train_acc: 0.3438 | test_loss: 1.0927 | test_acc: 0.4400
# Epoch: 6 | train_loss: 1.1068 | train_acc: 0.3320 | test_loss: 1.0953 | test_acc: 0.3333
# Epoch: 7 | train_loss: 1.0577 | train_acc: 0.5664 | test_loss: 1.0810 | test_acc: 0.3600
# Epoch: 8 | train_loss: 1.0632 | train_acc: 0.4414 | test_loss: 1.0672 | test_acc: 0.4000
# Epoch: 9 | train_loss: 0.9010 | train_acc: 0.6289 | test_loss: 1.0158 | test_acc: 0.4400
# Epoch: 10 | train_loss: 0.9994 | train_acc: 0.5156 | test_loss: 1.2129 | test_acc: 0.4667
# Epoch: 11 | train_loss: 0.9676 | train_acc: 0.5273 | test_loss: 1.0923 | test_acc: 0.4133
# Epoch: 12 | train_loss: 0.9999 | train_acc: 0.5703 | test_loss: 0.9837 | test_acc: 0.4533
# Epoch: 13 | train_loss: 0.8044 | train_acc: 0.6484 | test_loss: 1.0048 | test_acc: 0.4267
# Epoch: 14 | train_loss: 0.8014 | train_acc: 0.6562 | test_loss: 0.9730 | test_acc: 0.4267
# Epoch: 15 | train_loss: 0.8798 | train_acc: 0.5195 | test_loss: 0.9965 | test_acc: 0.4933
# Epoch: 16 | train_loss: 0.9106 | train_acc: 0.5430 | test_loss: 1.0123 | test_acc: 0.5067
# Epoch: 17 | train_loss: 0.9509 | train_acc: 0.5547 | test_loss: 0.9777 | test_acc: 0.4800
# Epoch: 18 | train_loss: 0.9011 | train_acc: 0.5703 | test_loss: 0.9641 | test_acc: 0.4267
# Epoch: 19 | train_loss: 0.8515 | train_acc: 0.6523 | test_loss: 0.9776 | test_acc: 0.4400
# Epoch: 20 | train_loss: 0.8215 | train_acc: 0.6836 | test_loss: 1.0145 | test_acc: 0.4133

# %% [markdown]
# ## Task 6: Make prediction on a custom image based on model_2

# %%
# Read a custom image from img_path and represent it as a tensor datatype
import torchvision

img_path = './data/'
custom_image = img_path + "img.jpeg"
img = torchvision.io.read_image(custom_image)

# %%
# Make a prediction on the image, put model_2 in eval mode
model_2.eval()
with torch.inference_mode():
  # Get image pixels into float + between 0 and 1
  img = img / 255.
  # -------------------- Complete the following lines ---------------------
  # Resize image to 64x64
  resize = transforms.Resize([64,64])
  img = resize(img)
  print('Resized image shape: \n',img.shape)
  # Turn image in single batch and pass to target device
  # add an additional dimension to img using unsqueeze()
  batch_img = img.unsqueeze(0).to(device) # modify this line!!!
  print('Add batch dim: \n', batch_img.shape)
  # Predict on image
  y_pred_logit = model_2(batch_img) 
  # ---------------------   End of code    ------------------------------
  # Convert pred logit to pred label
  pred_label = torch.argmax(y_pred_logit, dim=1)

# Plot the image and prediction
plt.imshow(img.permute(1, 2, 0))
plt.title(f"Pred label: {class_names[pred_label]}")
plt.axis(False)
# Out:
# Resized image shape:
#  torch.Size([3, 64, 64])
# Add batch dim:
#  torch.Size([1, 3, 64, 64])
# (-0.5, 63.5, 63.5, -0.5)

# %% [markdown]
# ### Analysis
# Does the model you trained get it right?
# If not, how to improve it?\
# **Your answer:**

# %% [markdown]
# Yes, I got the right result. But if I don't get it, we can adjust it in the following ways.
# First, we can adjust the parameters of the settings, for example: increase the training epoch of the model; reduce the learning rate of the model appropriately; set a reasonable batch size.
# Secondly, we can start by changing the model itself, for example: increasing the number of layers of the model, widening or deepening the network; adding a batch normalization layer to make the initialization of the weights better; changing the optimizer of the model to avoid falling into a local optimum.
# Finally, we can also use a larger dataset to increase the training sample of the model.

# %% [markdown]
# ## Advanced tasks
# ### A1: Train a complicated model (Use ResNet18 as an example) (10 points)

# %% [markdown]
# ### Read `Resnet18_pytorch.py` and complete the model file
# > If you finish `Resnet18_pytorch.py` correctly, run the following line will generate a vector with shape = ([1,3])

# %%
# %%bash
# python3.9 Resnet18_pytorch.py
# Out:
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 7, 7])
# torch.Size([1, 3])Output feature size.

# %%
from Resnet18_pytorch import ResNet, BasicBlock
torch.manual_seed(42)
model_resnet = ResNet(img_channels=3, num_layers=18, block=BasicBlock, num_classes=3).to(device)
model_resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# ### Preparing train dataloader and test dataloader

# %%
BATCH_SIZE=32
NUM_WORKERS=2
# ----- Complete the following transform functions -----
train_transform_augment = transforms.Compose([
    # Resize
    transforms.Resize([64,64]),
    # RandomHorizontalFlip
    transforms.RandomHorizontalFlip,
    # ToTensor
    transforms.ToTensor()
   
])
#  ----------------  End of code --------------------
train_data_augmented = datasets.ImageFolder(train_dir, transform=train_transform_augment)

train_dataloader_resnet = DataLoader(train_data,BATCH_SIZE,shuffle=True)

test_dataloader_simple = DataLoader(test_data,BATCH_SIZE,shuffle=False)

train_dataloader_resnet, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7f56ec1d83a0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f56f46fff70>)

# %% [markdown]
# #### Start training

# %%
# Set random seeds
torch.manual_seed(42) 
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_1.parameters(), lr=0.001)

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# Train model
model_resnet_results = train(model_resnet,train_dataloader,test_dataloader,optimizer,loss_fn,NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Epoch: 1 | train_loss: 1.1108 | train_acc: 0.3156 | test_loss: 1.1469 | test_acc: 0.3467
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Epoch: 2 | train_loss: 1.1142 | train_acc: 0.3244 | test_loss: 1.1421 | test_acc: 0.3200
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# ...
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 2, 2])
# Epoch: 5 | train_loss: 1.1164 | train_acc: 0.3067 | test_loss: 1.1435 | test_acc: 0.2933
# Total training time: 32.617 seconds

# %% [markdown]
# ### A2: Compare model performance (5 points)
# Choose a previous model used in **Task 3** (model_0) or **Task 4** (model_1) to compare with ResNet18 model

# %%
from torchinfo import summary
summary(model_resnet, input_size=[1, 3, 224, 224]) # do a test pass through of an example input size
# Out:
# Dimensions of the last convolutional feature map:  torch.Size([1, 512, 7, 7])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 3]                    --
# ├─Conv2d: 1-1                            [1, 64, 112, 112]         9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         128
# ├─ReLU: 1-3                              [1, 64, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 64, 56, 56]           --
# ├─Sequential: 1-5                        [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-1                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-3                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-4                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-5             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-6                    [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-2                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-8             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-9                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-10                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-11            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-12                   [1, 64, 56, 56]           --
# ├─Sequential: 1-6                        [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-3                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-13                 [1, 128, 28, 28]          73,728
# │    │    └─BatchNorm2d: 3-14            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-15                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-16                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-17            [1, 128, 28, 28]          256
# │    │    └─Sequential: 3-18             [1, 128, 28, 28]          8,448
# │    │    └─ReLU: 3-19                   [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-4                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-20                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-21            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-22                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-23                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-24            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-25                   [1, 128, 28, 28]          --
# ├─Sequential: 1-7                        [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-5                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-26                 [1, 256, 14, 14]          294,912
# │    │    └─BatchNorm2d: 3-27            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-28                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-29                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-30            [1, 256, 14, 14]          512
# │    │    └─Sequential: 3-31             [1, 256, 14, 14]          33,280
# │    │    └─ReLU: 3-32                   [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-6                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-33                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-34            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-35                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-36                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-37            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-38                   [1, 256, 14, 14]          --
# ├─Sequential: 1-8                        [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-7                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-39                 [1, 512, 7, 7]            1,179,648
# │    │    └─BatchNorm2d: 3-40            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-41                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-42                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-43            [1, 512, 7, 7]            1,024
# │    │    └─Sequential: 3-44             [1, 512, 7, 7]            132,096
# │    │    └─ReLU: 3-45                   [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-8                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-46                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-47            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-48                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-50            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-51                   [1, 512, 7, 7]            --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 512, 1, 1]            --
# ├─Linear: 1-10                           [1, 3]                    1,539
# ==========================================================================================
# Total params: 11,178,051
# Trainable params: 11,178,051
# Non-trainable params: 0
# Total mult-adds (G): 1.81
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 39.74
# Params size (MB): 44.71
# Estimated Total Size (MB): 85.05
# ==========================================================================================

# %% [markdown]
# ### Plot the train_loss and test_loss of model_resnet and a previous model using subplot function

# %%
import pandas as pd
model_0_df = pd.DataFrame(model_0_results) # Or model_1

model_resnet_df = pd.DataFrame(model_resnet_results)
model_0_df, model_resnet_df
# Out:
# (   train_loss  train_acc  test_loss  test_acc
#  0    1.100144   0.262222   1.100702  0.226667
#  1    1.099796   0.320000   1.102142  0.333333
#  2    1.099610   0.320000   1.102116  0.333333
#  3    1.099174   0.346667   1.101920  0.333333
#  4    1.099293   0.333333   1.101375  0.333333,
#     train_loss  train_acc  test_loss  test_acc
#  0    1.110834   0.315556   1.146930  0.346667
#  1    1.114246   0.324444   1.142126  0.320000
#  2    1.116933   0.315556   1.179109  0.386667
#  3    1.116652   0.306667   1.135234  0.346667
#  4    1.116433   0.306667   1.143519  0.293333)

# %%
# ------ Complete subplot functions in the following lines -------
plt.figure(figsize=(15, 10))

# Get number of epochs
epochs = range(len(model_0_df))

# Plot train loss with label, title, legend
plt.subplot(2, 2, 1)
plt.plot(epochs,model_0_df['train_loss'], label = 'model_0')   # plot epochs, train_loss
plt.plot(epochs,model_resnet_df['train_loss'], label = 'model_resnet')   # plot epochs, test_loss
plt.title('train_loss')
plt.xlabel('epochs')
plt.legend()

# Plot test loss
plt.subplot(2, 2, 2)

plt.plot(epochs,model_0_df['test_loss'], label = 'model_0')   # plot epochs, train_loss
plt.plot(epochs,model_resnet_df['test_loss'], label = 'model_resnet')   # plot epochs, test_loss
plt.title('test_loss')
plt.xlabel('epochs')


plt.legend()

# Plot train accuracy
plt.subplot(2, 2, 3)
 
plt.plot(epochs,model_0_df['train_acc'], label = 'model_0')   # plot epochs, train_loss
plt.plot(epochs,model_resnet_df['train_acc'], label = 'model_resnet')   # plot epochs, test_loss
plt.title('train_acc')
plt.xlabel('epochs')


plt.legend()

# Plot test accuracy
plt.subplot(2, 2, 4)

plt.plot(epochs,model_0_df['test_acc'], label = 'model_0')   # plot epochs, train_loss
plt.plot(epochs,model_resnet_df['test_acc'], label = 'model_resnet')   # plot epochs, test_loss
plt.title('test_acc')
plt.xlabel('epochs')


plt.legend()

# %% [markdown]
# ### A3: Git version control (5 points)
# Please insert an image in the cell to show your git log

# %% [markdown]
# ### Git version control advices
# 1. Create a remote repo, upload this notebote to the repo\
#    **Take a screenshot of the inital status**
# 2. git clone (ssh link of the repo)
# 3. Make some modifications to the files
# 4. git add .
# 5. git commit -m "leave some message here"
# 6. git push
# 7. git log
# 8. check the remote repo, **Take a screenshot after git push operations**

# %%
from IPython.display import Image

# %%
Image("git pull.png",width=994,height=655)

# %%
Image("git merge.png")

# %%
Image("git push steps.png")

# %%
Image("before.png")

# %%
Image("after.png")

# %%
Image("gitlog.png")
